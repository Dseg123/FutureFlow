# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
deep_1 = '/home/dylaneg/Documents/Programming/IROM/FutureFlow/FutureFlow_DEG/experiments/Big_1_Deep_Reg_2024-01-10_23:49:02'
deep_2 = '/home/dylaneg/Documents/Programming/IROM/FutureFlow/FutureFlow_DEG/experiments/Big_2_Deep_Reg_2024-01-07_22:55:59'
deep_3 = '/home/dylaneg/Documents/Programming/IROM/FutureFlow/FutureFlow_DEG/experiments/Big_3_Deep_Reg_2024-01-11_10:41:27'
paths = [deep_1, deep_2, deep_3]
names = ['Deep_1', 'Deep_2', 'Deep_3']
train_losses = []
test_losses = []
for path in paths:
    print(path)
    train_losses.append(get_train_loss(path))
    test_losses.append(get_test_loss(path))

x = np.arange(1, 4)
plt.bar(x, test_losses, tick_label=names)
plt.rcParams['xtick.labelsize'] = 'small'
# plt.tight_layout()
plt.xlabel("Model Type")
plt.ylabel("MSE Loss")
plt.title("Test Losses of the DNN Models")
plt.ylim([0.45, 0.5])
# Out:
# /home/dylaneg/Documents/Programming/IROM/FutureFlow/FutureFlow_DEG/experiments/Big_1_Deep_Reg_2024-01-10_23:49:02
# /home/dylaneg/Documents/Programming/IROM/FutureFlow/FutureFlow_DEG/experiments/Big_2_Deep_Reg_2024-01-07_22:55:59
# /home/dylaneg/Documents/Programming/IROM/FutureFlow/FutureFlow_DEG/experiments/Big_3_Deep_Reg_2024-01-11_10:41:27
# (0.45, 0.5)

# %%
print((max(test_losses) - min(test_losses))/max(test_losses))
# Out:
# 0.006788111008051698

# %%
persistent = "/home/dylaneg/Documents/Programming/IROM/FutureFlow/FutureFlow_DEG/experiments/Big_Naive_2024-01-07_11:39:07"
lin_reg = "/home/dylaneg/Documents/Programming/IROM/FutureFlow/FutureFlow_DEG/experiments/Big_Lin_Reg_2024-01-08_07:51:41"
lin_reg_flat = "/home/dylaneg/Documents/Programming/IROM/FutureFlow/FutureFlow_DEG/experiments/Big_Lin_Reg_Flat_2024-01-08_01:31:26"
deep_1 = "/home/dylaneg/Documents/Programming/IROM/FutureFlow/FutureFlow_DEG/experiments/VK_Deep_Reg_2024-01-06_11:22:45"
deep_2 = "/home/dylaneg/Documents/Programming/IROM/FutureFlow/FutureFlow_DEG/experiments/Big_Deep_Reg_2024-01-07_22:55:59"
deep_3 = "/home/dylaneg/Documents/Programming/IROM/FutureFlow/FutureFlow_DEG/experiments/VK_Deep_Reg_2024-01-06_11:40:14"
rnn = "/home/dylaneg/Documents/Programming/IROM/FutureFlow/FutureFlow_DEG/experiments/Big_RNN_2024-01-06_21:21:57"
lstm = "/home/dylaneg/Documents/Programming/IROM/FutureFlow/FutureFlow_DEG/experiments/Big_LSTM_2024-01-07_02:21:26"
transformer = "/home/dylaneg/Documents/Programming/IROM/FutureFlow/FutureFlow_DEG/experiments/Big_Transformer_2024-01-06_16:03:52"
annmc = "/home/dylaneg/Documents/Programming/IROM/FutureFlow/FutureFlow_DEG/experiments/Big_ANNMC_2024-01-07_12:16:39"
paths = [persistent, lin_reg, lin_reg_flat, deep_2, rnn, lstm, transformer, annmc]

# %%
def get_train_loss(experiment_path):
    df = pd.read_csv(experiment_path + '/log.csv')
    train_losses = df['train_losses']
    return train_losses.min()

def get_test_loss(experiment_path):
    df = pd.read_csv(experiment_path + '/log.csv')
    test_losses = df['test_losses']
    return test_losses.min()

# %%
for path in paths:
    print(path + ": " + str(get_train_loss(path)))
# Out:
# /home/dylaneg/Documents/Programming/IROM/FutureFlow/FutureFlow_DEG/experiments/Big_Naive_2024-01-07_11:39:07: 0.2397124523693234
# /home/dylaneg/Documents/Programming/IROM/FutureFlow/FutureFlow_DEG/experiments/Big_Lin_Reg_2024-01-08_07:51:41: 0.172355260731496
# /home/dylaneg/Documents/Programming/IROM/FutureFlow/FutureFlow_DEG/experiments/Big_Lin_Reg_Flat_2024-01-08_01:31:26: 0.1716332167687552
# /home/dylaneg/Documents/Programming/IROM/FutureFlow/FutureFlow_DEG/experiments/Big_Deep_Reg_2024-01-07_22:55:59: 0.1653458437977495
# /home/dylaneg/Documents/Programming/IROM/FutureFlow/FutureFlow_DEG/experiments/Big_RNN_2024-01-06_21:21:57: 0.170860491194941
# /home/dylaneg/Documents/Programming/IROM/FutureFlow/FutureFlow_DEG/experiments/Big_LSTM_2024-01-07_02:21:26: 0.1641325973454201
# /home/dylaneg/Documents/Programming/IROM/FutureFlow/FutureFlow_DEG/experiments/Big_Transformer_2024-01-06_16:03:52: 0.1632798885026947
# ...

# %%
for path in paths:
    print(path + ": " + str(get_test_loss(path)))
# Out:
# /home/dylaneg/Documents/Programming/IROM/FutureFlow/FutureFlow_DEG/experiments/Big_Naive_2024-01-07_11:39:07: 0.7033570534273953
# /home/dylaneg/Documents/Programming/IROM/FutureFlow/FutureFlow_DEG/experiments/Big_Lin_Reg_2024-01-08_07:51:41: 0.4922922949513291
# /home/dylaneg/Documents/Programming/IROM/FutureFlow/FutureFlow_DEG/experiments/Big_Lin_Reg_Flat_2024-01-08_01:31:26: 0.4870033180201759
# /home/dylaneg/Documents/Programming/IROM/FutureFlow/FutureFlow_DEG/experiments/Big_Deep_Reg_2024-01-07_22:55:59: 0.4767977662030643
# /home/dylaneg/Documents/Programming/IROM/FutureFlow/FutureFlow_DEG/experiments/Big_RNN_2024-01-06_21:21:57: 0.4916507630047274
# /home/dylaneg/Documents/Programming/IROM/FutureFlow/FutureFlow_DEG/experiments/Big_LSTM_2024-01-07_02:21:26: 0.4850811718653454
# /home/dylaneg/Documents/Programming/IROM/FutureFlow/FutureFlow_DEG/experiments/Big_Transformer_2024-01-06_16:03:52: 0.4741382057157655
# ...

# %%
names = ["Pers", "Lin_reg", "Lin_flat", "Deep", "RNN", "LSTM", "Trans", "ANNMC"]
train_losses = []
test_losses = []

# %%
x = np.arange(1, 9)

# %%
for path in paths:
    print(path)
    train_losses.append(get_train_loss(path))
    test_losses.append(get_test_loss(path))
# Out:
# /home/dylaneg/Documents/Programming/IROM/FutureFlow/FutureFlow_DEG/experiments/Big_Naive_2024-01-07_11:39:07
# /home/dylaneg/Documents/Programming/IROM/FutureFlow/FutureFlow_DEG/experiments/Big_Lin_Reg_2024-01-08_07:51:41
# /home/dylaneg/Documents/Programming/IROM/FutureFlow/FutureFlow_DEG/experiments/Big_Lin_Reg_Flat_2024-01-08_01:31:26
# /home/dylaneg/Documents/Programming/IROM/FutureFlow/FutureFlow_DEG/experiments/Big_Deep_Reg_2024-01-07_22:55:59
# /home/dylaneg/Documents/Programming/IROM/FutureFlow/FutureFlow_DEG/experiments/Big_RNN_2024-01-06_21:21:57
# /home/dylaneg/Documents/Programming/IROM/FutureFlow/FutureFlow_DEG/experiments/Big_LSTM_2024-01-07_02:21:26
# /home/dylaneg/Documents/Programming/IROM/FutureFlow/FutureFlow_DEG/experiments/Big_Transformer_2024-01-06_16:03:52
# /home/dylaneg/Documents/Programming/IROM/FutureFlow/FutureFlow_DEG/experiments/Big_ANNMC_2024-01-07_12:16:39

# %%
print(len(x))
print(len(train_losses))
# Out:
# 9
# 8

# %%
plt.bar(x, train_losses, tick_label=names)
plt.rcParams['xtick.labelsize'] = 'small'
# plt.tight_layout()
plt.xlabel("Model Type")
plt.ylabel("MSE Loss")
plt.title("Train Losses of the Real-World Models")
plt.ylim([0.1, 0.3])
# Out:
# (0.1, 0.3)

# %%
plt.bar(x, test_losses, tick_label=names)
plt.rcParams['xtick.labelsize'] = 'small'
# plt.tight_layout()
plt.xlabel("Model Type")
plt.ylabel("MSE Loss")
plt.title("Test Losses of the Real-World Models")
plt.ylim([0.4, 0.8])
# Out:
# (0.4, 0.8)

# %%
for i in range(1, len(paths)):
    path = paths[i]
    name = names[i]
    log = pd.read_csv(path + '/log.csv')
    # print(log['train_losses'])
    # print(log['test_losses'])
    plt.plot(log['train_losses'], label="train")
    plt.plot(log['test_losses'], label="test")
    plt.xlabel('Epoch')
    plt.ylabel('MSE Loss')
    plt.title(f'Loss Curve of {name}')
    plt.ylim([0, 0.6])
    plt.legend()
    plt.show()

# %%
path = lin_reg
log = pd.read_csv(path + '/log.csv')
print(log['train_losses'])
print(log['test_losses'])
plt.plot(log['train_losses'], label="train")
plt.plot(log['test_losses'], label="test")
plt.xlabel('Epoch')
plt.ylabel('MSE Loss')
plt.title('Loss Curve of Pers')
plt.legend()
plt.show()
# Out:
# 0     0.290620
# 1     0.181159
# 2     0.175785
# 3     0.174051
# 4     0.173273
# 5     0.172871
# 6     0.172669
# 7     0.172546
# 8     0.172486
# 9     0.172437
# 10    0.172405
# 11    0.172398
# 12    0.172379
# 13    0.172383
# 14    0.172374
# 15    0.172368
# 16    0.172366
# 17    0.172358
# 18    0.172355
# 19    0.172359
# 20    0.172370
# 21    0.172364
# 22    0.172370
# 23    0.172366
# 24    0.172361
# 25    0.172370
# 26    0.172371
# 27    0.172362
# 28    0.172358
# 29    0.172360
# Name: train_losses, dtype: float64
# 0     0.537366
# 1     0.508710
# 2     0.499728
# 3     0.496682
# 4     0.494713
# 5     0.493462
# 6     0.493985
# 7     0.493569
# 8     0.492864
# 9     0.493061
# 10    0.494110
# 11    0.493018
# 12    0.493812
# 13    0.493917
# 14    0.492742
# 15    0.492292
# 16    0.492698
# 17    0.492575
# 18    0.493227
# 19    0.493260
# 20    0.493151
# 21    0.492945
# 22    0.493035
# 23    0.493405
# 24    0.492430
# 25    0.492991
# ...
