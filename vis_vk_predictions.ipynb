# %%
# %load_ext autoreload
# %autoreload 2

# %%
import visualizations

# %%
import numpy as np

# %%
import pandas as pd

# %%
import models
import torch

# %%
df = pd.read_csv('von_karman_data.csv')

# %%
df2 = pd.read_csv('sample_data.csv')

# %%
plt.plot(df['w'][:100])
plt.plot(df2['w'][:100])

# %%
print(df['u'].mean())
# Out:
# 1.4021267746884853

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(df2['u'])

# %% [markdown]
# ## Combined VK Visualization

# %%
vk_persistent = "/home/dylaneg/Documents/Programming/IROM/FutureFlow/FutureFlow_DEG/experiments/VK_Naive_2024-01-06_10:30:18"
vk_lin_reg = "/home/dylaneg/Documents/Programming/IROM/FutureFlow/FutureFlow_DEG/experiments/VK_Lin_Reg_2024-01-06_15:04:13"
vk_lin_reg_flat = "/home/dylaneg/Documents/Programming/IROM/FutureFlow/FutureFlow_DEG/experiments/VK_Lin_Reg_Flat_2024-01-06_10:39:01"
vk_deep_1 = "/home/dylaneg/Documents/Programming/IROM/FutureFlow/FutureFlow_DEG/experiments/VK_Deep_Reg_2024-01-06_11:22:45"
vk_deep_2 = "/home/dylaneg/Documents/Programming/IROM/FutureFlow/FutureFlow_DEG/experiments/VK_Deep_Reg_2024-01-06_10:43:27"
vk_deep_3 = "/home/dylaneg/Documents/Programming/IROM/FutureFlow/FutureFlow_DEG/experiments/VK_Deep_Reg_2024-01-06_11:40:14"
vk_rnn = "/home/dylaneg/Documents/Programming/IROM/FutureFlow/FutureFlow_DEG/experiments/VK_RNN_2024-01-06_11:46:35"
vk_lstm = "/home/dylaneg/Documents/Programming/IROM/FutureFlow/FutureFlow_DEG/experiments/VK_LSTM_2024-01-06_11:58:26"
vk_transformer = "/home/dylaneg/Documents/Programming/IROM/FutureFlow/FutureFlow_DEG/experiments/VK_Transformer_2024-01-06_15:07:04"
vk_annmc = "/home/dylaneg/Documents/Programming/IROM/FutureFlow/FutureFlow_DEG/experiments/VK_ANNMC_2024-01-06_13:17:38"

# %%
data_df = pd.read_csv('von_karman_data.csv')
experiment_path = vk_persistent
params = pd.read_csv(experiment_path + "/params.csv")
input_length = int(params.iloc[0]['input_length'])
output_length = int(params.iloc[0]['output_length'])
input_width = int(params.iloc[0]['input_width'])
hidden_size = int(params.iloc[0]['hidden_size'])
num_layers = int(params.iloc[0]['num_layers'])
tpm = np.load('tpm.npy')
print(input_length, output_length, input_width, hidden_size, num_layers)
# tpm = np.load('tpm.npy')
model = models.NaiveModel(input_width=input_width, input_length=input_length, output_length=output_length)
# model.load_state_dict(torch.load(experiment_path + '/weights.pt'))
# visualizations.display_preds(model, data_df, input_length, ['u', 'v', 'w'])
vk_persistent_preds, trues = visualizations.get_preds(model, data_df, input_length, ['u', 'v', 'w'])
# Out:
# 50 10 3 50 2
# 500000
# 497950
# (1, 10, 3)
# (3,)
# 497951
# (1, 10, 3)
# (3,)
# 497952
# (1, 10, 3)
# (3,)
# 497953
# (1, 10, 3)
# (3,)
# 497954
# (1, 10, 3)
# (3,)
# 497955
# (1, 10, 3)
# (3,)
# 497956
# (1, 10, 3)
# (3,)
# 497957
# (1, 10, 3)
# (3,)
# 497958
# (1, 10, 3)
# (3,)
# 497959
# (1, 10, 3)
# (3,)
# 497960
# (1, 10, 3)
# (3,)
# 497961
# (1, 10, 3)
# (3,)
# 497962
# (1, 10, 3)
# (3,)
# 497963
# (1, 10, 3)
# (3,)
# 497964
# (1, 10, 3)
# (3,)
# 497965
# (1, 10, 3)
# (3,)
# 497966
# (1, 10, 3)
# (3,)
# 497967
# (1, 10, 3)
# (3,)
# 497968
# (1, 10, 3)
# (3,)
# 497969
# (1, 10, 3)
# (3,)
# 497970
# (1, 10, 3)
# (3,)
# 497971
# (1, 10, 3)
# (3,)
# 497972
# (1, 10, 3)
# (3,)
# 497973
# (1, 10, 3)
# (3,)
# 497974
# (1, 10, 3)
# (3,)
# 497975
# (1, 10, 3)
# (3,)
# 497976
# (1, 10, 3)
# (3,)
# 497977
# (1, 10, 3)
# (3,)
# 497978
# (1, 10, 3)
# (3,)
# 497979
# (1, 10, 3)
# (3,)
# 497980
# (1, 10, 3)
# (3,)
# 497981
# (1, 10, 3)
# (3,)
# 497982
# (1, 10, 3)
# (3,)
# 497983
# ...

# %%
print(trues)
print(vk_persistent_preds)
# Out:
# [[0.44485265016555786, 1.2537240982055664, -0.012670478783547878], [-0.9190925359725952, 1.1979975700378418, -0.29004254937171936], [-0.40018802881240845, 0.9421652555465698, -0.4944145977497101], [-0.30052879452705383, 1.535364031791687, -0.6515837907791138], [-0.39691898226737976, 2.5540032386779785, -0.35807865858078003], [0.08667602390050888, 2.3299801349639893, -0.4752379059791565], [0.050943005830049515, 2.7492027282714844, -0.6346316933631897], [-0.7998793721199036, 2.8935468196868896, -0.6572182774543762], [-0.5980304479598999, 2.260552406311035, -0.785597562789917], [-0.7849469780921936, 2.826219081878662, -0.9472556114196777], [-0.36669668555259705, 2.390366792678833, -1.0452442169189453], [-0.6092843413352966, 2.0893568992614746, -0.8110657930374146], [-0.9534997344017029, 1.927039623260498, -0.6283481121063232], [-1.6339235305786133, 1.5939635038375854, -0.6132499575614929], [-2.393328905105591, 1.5536457300186157, -0.6821962594985962], [-1.5140780210494995, 1.71479821205
# ...

# %%
data_df = pd.read_csv('von_karman_data.csv')
experiment_path = vk_lin_reg
params = pd.read_csv(experiment_path + "/params.csv")
input_length = int(params.iloc[0]['input_length'])
output_length = int(params.iloc[0]['output_length'])
input_width = int(params.iloc[0]['input_width'])
hidden_size = int(params.iloc[0]['hidden_size'])
num_layers = int(params.iloc[0]['num_layers'])
tpm = np.load('tpm.npy')
print(input_length, output_length, input_width, hidden_size, num_layers)
# tpm = np.load('tpm.npy')
model = models.LinearRegression(input_width=input_width, input_length=input_length, output_length=output_length)
# Model(input_width=input_width, input_length=input_length, output_length=output_length)
model.load_state_dict(torch.load(experiment_path + '/weights.pt'))
# visualizations.display_preds(model, data_df, input_length, ['u', 'v', 'w'])
vk_lin_reg_preds, trues = visualizations.get_preds(model, data_df, input_length, ['u', 'v', 'w'])
# Out:
# 50 10 3 50 2
# 500000
# 497950
# (1, 10, 3)
# (3,)
# 497951
# (1, 10, 3)
# (3,)
# 497952
# (1, 10, 3)
# (3,)
# 497953
# (1, 10, 3)
# (3,)
# 497954
# (1, 10, 3)
# (3,)
# 497955
# (1, 10, 3)
# (3,)
# 497956
# (1, 10, 3)
# (3,)
# 497957
# (1, 10, 3)
# (3,)
# 497958
# (1, 10, 3)
# (3,)
# 497959
# (1, 10, 3)
# (3,)
# 497960
# (1, 10, 3)
# (3,)
# 497961
# (1, 10, 3)
# (3,)
# 497962
# (1, 10, 3)
# (3,)
# 497963
# (1, 10, 3)
# (3,)
# 497964
# (1, 10, 3)
# (3,)
# 497965
# (1, 10, 3)
# (3,)
# 497966
# (1, 10, 3)
# (3,)
# 497967
# (1, 10, 3)
# (3,)
# 497968
# (1, 10, 3)
# (3,)
# 497969
# (1, 10, 3)
# (3,)
# 497970
# (1, 10, 3)
# (3,)
# 497971
# (1, 10, 3)
# (3,)
# 497972
# (1, 10, 3)
# (3,)
# 497973
# (1, 10, 3)
# (3,)
# 497974
# (1, 10, 3)
# (3,)
# 497975
# (1, 10, 3)
# (3,)
# 497976
# (1, 10, 3)
# (3,)
# 497977
# (1, 10, 3)
# (3,)
# 497978
# (1, 10, 3)
# (3,)
# 497979
# (1, 10, 3)
# (3,)
# 497980
# (1, 10, 3)
# (3,)
# 497981
# (1, 10, 3)
# (3,)
# 497982
# (1, 10, 3)
# (3,)
# 497983
# ...

# %%
data_df = pd.read_csv('von_karman_data.csv')
experiment_path = vk_lin_reg_flat
params = pd.read_csv(experiment_path + "/params.csv")
input_length = int(params.iloc[0]['input_length'])
output_length = int(params.iloc[0]['output_length'])
input_width = int(params.iloc[0]['input_width'])
hidden_size = int(params.iloc[0]['hidden_size'])
num_layers = int(params.iloc[0]['num_layers'])
tpm = np.load('tpm.npy')
print(input_length, output_length, input_width, hidden_size, num_layers)
# tpm = np.load('tpm.npy')
model = models.LinearRegressionFlat(input_width=input_width, input_length=input_length, output_length=output_length)
# Model(input_width=input_width, input_length=input_length, output_length=output_length)
model.load_state_dict(torch.load(experiment_path + '/weights.pt'))
# visualizations.display_preds(model, data_df, input_length, ['u', 'v', 'w'])
vk_lin_reg_flat_preds, trues = visualizations.get_preds(model, data_df, input_length, ['u', 'v', 'w'])
# Out:
# 50 10 3 50 2
# 500000
# 497950
# (1, 10, 3)
# (3,)
# 497951
# (1, 10, 3)
# (3,)
# 497952
# (1, 10, 3)
# (3,)
# 497953
# (1, 10, 3)
# (3,)
# 497954
# (1, 10, 3)
# (3,)
# 497955
# (1, 10, 3)
# (3,)
# 497956
# (1, 10, 3)
# (3,)
# 497957
# (1, 10, 3)
# (3,)
# 497958
# (1, 10, 3)
# (3,)
# 497959
# (1, 10, 3)
# (3,)
# 497960
# (1, 10, 3)
# (3,)
# 497961
# (1, 10, 3)
# (3,)
# 497962
# (1, 10, 3)
# (3,)
# 497963
# (1, 10, 3)
# (3,)
# 497964
# (1, 10, 3)
# (3,)
# 497965
# (1, 10, 3)
# (3,)
# 497966
# (1, 10, 3)
# (3,)
# 497967
# (1, 10, 3)
# (3,)
# 497968
# (1, 10, 3)
# (3,)
# 497969
# (1, 10, 3)
# (3,)
# 497970
# (1, 10, 3)
# (3,)
# 497971
# (1, 10, 3)
# (3,)
# 497972
# (1, 10, 3)
# (3,)
# 497973
# (1, 10, 3)
# (3,)
# 497974
# (1, 10, 3)
# (3,)
# 497975
# (1, 10, 3)
# (3,)
# 497976
# (1, 10, 3)
# (3,)
# 497977
# (1, 10, 3)
# (3,)
# 497978
# (1, 10, 3)
# (3,)
# 497979
# (1, 10, 3)
# (3,)
# 497980
# (1, 10, 3)
# (3,)
# 497981
# (1, 10, 3)
# (3,)
# 497982
# (1, 10, 3)
# (3,)
# 497983
# ...

# %%
data_df = pd.read_csv('von_karman_data.csv')
experiment_path = vk_deep_1
params = pd.read_csv(experiment_path + "/params.csv")
input_length = int(params.iloc[0]['input_length'])
output_length = int(params.iloc[0]['output_length'])
input_width = int(params.iloc[0]['input_width'])
hidden_size = int(params.iloc[0]['hidden_size'])
num_layers = int(params.iloc[0]['num_layers'])
tpm = np.load('tpm.npy')
print(input_length, output_length, input_width, hidden_size, num_layers)
# tpm = np.load('tpm.npy')
model = models.DeepRegression(input_width=input_width, input_length=input_length, output_length=output_length, layer_sizes=[100])
# Model(input_width=input_width, input_length=input_length, output_length=output_length)
model.load_state_dict(torch.load(experiment_path + '/weights.pt'))
# visualizations.display_preds(model, data_df, input_length, ['u', 'v', 'w'])
vk_deep_1_preds, trues = visualizations.get_preds(model, data_df, input_length, ['u', 'v', 'w'])
# Out:
# 50 10 3 50 2
# 500000
# 497950
# (1, 10, 3)
# (3,)
# 497951
# (1, 10, 3)
# (3,)
# 497952
# (1, 10, 3)
# (3,)
# 497953
# (1, 10, 3)
# (3,)
# 497954
# (1, 10, 3)
# (3,)
# 497955
# (1, 10, 3)
# (3,)
# 497956
# (1, 10, 3)
# (3,)
# 497957
# (1, 10, 3)
# (3,)
# 497958
# (1, 10, 3)
# (3,)
# 497959
# (1, 10, 3)
# (3,)
# 497960
# (1, 10, 3)
# (3,)
# 497961
# (1, 10, 3)
# (3,)
# 497962
# (1, 10, 3)
# (3,)
# 497963
# (1, 10, 3)
# (3,)
# 497964
# (1, 10, 3)
# (3,)
# 497965
# (1, 10, 3)
# (3,)
# 497966
# (1, 10, 3)
# (3,)
# 497967
# (1, 10, 3)
# (3,)
# 497968
# (1, 10, 3)
# (3,)
# 497969
# (1, 10, 3)
# (3,)
# 497970
# (1, 10, 3)
# (3,)
# 497971
# (1, 10, 3)
# (3,)
# 497972
# (1, 10, 3)
# (3,)
# 497973
# (1, 10, 3)
# (3,)
# 497974
# (1, 10, 3)
# (3,)
# 497975
# (1, 10, 3)
# (3,)
# 497976
# (1, 10, 3)
# (3,)
# 497977
# (1, 10, 3)
# (3,)
# 497978
# (1, 10, 3)
# (3,)
# 497979
# (1, 10, 3)
# (3,)
# 497980
# (1, 10, 3)
# (3,)
# 497981
# (1, 10, 3)
# (3,)
# 497982
# (1, 10, 3)
# (3,)
# 497983
# ...

# %%
data_df = pd.read_csv('von_karman_data.csv')
experiment_path = vk_deep_2
params = pd.read_csv(experiment_path + "/params.csv")
input_length = int(params.iloc[0]['input_length'])
output_length = int(params.iloc[0]['output_length'])
input_width = int(params.iloc[0]['input_width'])
hidden_size = int(params.iloc[0]['hidden_size'])
num_layers = int(params.iloc[0]['num_layers'])
tpm = np.load('tpm.npy')
print(input_length, output_length, input_width, hidden_size, num_layers)
# tpm = np.load('tpm.npy')
model = models.DeepRegression(input_width=input_width, input_length=input_length, output_length=output_length, layer_sizes=[50, 50])
# Model(input_width=input_width, input_length=input_length, output_length=output_length)
model.load_state_dict(torch.load(experiment_path + '/weights.pt'))
# visualizations.display_preds(model, data_df, input_length, ['u', 'v', 'w'])
vk_deep_2_preds, trues = visualizations.get_preds(model, data_df, input_length, ['u', 'v', 'w'])
# Out:
# 50 10 3 50 2
# 500000
# 497950
# (1, 10, 3)
# (3,)
# 497951
# (1, 10, 3)
# (3,)
# 497952
# (1, 10, 3)
# (3,)
# 497953
# (1, 10, 3)
# (3,)
# 497954
# (1, 10, 3)
# (3,)
# 497955
# (1, 10, 3)
# (3,)
# 497956
# (1, 10, 3)
# (3,)
# 497957
# (1, 10, 3)
# (3,)
# 497958
# (1, 10, 3)
# (3,)
# 497959
# (1, 10, 3)
# (3,)
# 497960
# (1, 10, 3)
# (3,)
# 497961
# (1, 10, 3)
# (3,)
# 497962
# (1, 10, 3)
# (3,)
# 497963
# (1, 10, 3)
# (3,)
# 497964
# (1, 10, 3)
# (3,)
# 497965
# (1, 10, 3)
# (3,)
# 497966
# (1, 10, 3)
# (3,)
# 497967
# (1, 10, 3)
# (3,)
# 497968
# (1, 10, 3)
# (3,)
# 497969
# (1, 10, 3)
# (3,)
# 497970
# (1, 10, 3)
# (3,)
# 497971
# (1, 10, 3)
# (3,)
# 497972
# (1, 10, 3)
# (3,)
# 497973
# (1, 10, 3)
# (3,)
# 497974
# (1, 10, 3)
# (3,)
# 497975
# (1, 10, 3)
# (3,)
# 497976
# (1, 10, 3)
# (3,)
# 497977
# (1, 10, 3)
# (3,)
# 497978
# (1, 10, 3)
# (3,)
# 497979
# (1, 10, 3)
# (3,)
# 497980
# (1, 10, 3)
# (3,)
# 497981
# (1, 10, 3)
# (3,)
# 497982
# (1, 10, 3)
# (3,)
# 497983
# ...

# %%
data_df = pd.read_csv('von_karman_data.csv')
experiment_path = vk_deep_3
params = pd.read_csv(experiment_path + "/params.csv")
input_length = int(params.iloc[0]['input_length'])
output_length = int(params.iloc[0]['output_length'])
input_width = int(params.iloc[0]['input_width'])
hidden_size = int(params.iloc[0]['hidden_size'])
num_layers = int(params.iloc[0]['num_layers'])
tpm = np.load('tpm.npy')
print(input_length, output_length, input_width, hidden_size, num_layers)
# tpm = np.load('tpm.npy')
model = models.DeepRegression(input_width=input_width, input_length=input_length, output_length=output_length, layer_sizes=[32, 32, 32])
# Model(input_width=input_width, input_length=input_length, output_length=output_length)
model.load_state_dict(torch.load(experiment_path + '/weights.pt'))
# visualizations.display_preds(model, data_df, input_length, ['u', 'v', 'w'])
vk_deep_3_preds, trues = visualizations.get_preds(model, data_df, input_length, ['u', 'v', 'w'])
# Out:
# 50 10 3 50 2
# 500000
# 497950
# (1, 10, 3)
# (3,)
# 497951
# (1, 10, 3)
# (3,)
# 497952
# (1, 10, 3)
# (3,)
# 497953
# (1, 10, 3)
# (3,)
# 497954
# (1, 10, 3)
# (3,)
# 497955
# (1, 10, 3)
# (3,)
# 497956
# (1, 10, 3)
# (3,)
# 497957
# (1, 10, 3)
# (3,)
# 497958
# (1, 10, 3)
# (3,)
# 497959
# (1, 10, 3)
# (3,)
# 497960
# (1, 10, 3)
# (3,)
# 497961
# (1, 10, 3)
# (3,)
# 497962
# (1, 10, 3)
# (3,)
# 497963
# (1, 10, 3)
# (3,)
# 497964
# (1, 10, 3)
# (3,)
# 497965
# (1, 10, 3)
# (3,)
# 497966
# (1, 10, 3)
# (3,)
# 497967
# (1, 10, 3)
# (3,)
# 497968
# (1, 10, 3)
# (3,)
# 497969
# (1, 10, 3)
# (3,)
# 497970
# (1, 10, 3)
# (3,)
# 497971
# (1, 10, 3)
# (3,)
# 497972
# (1, 10, 3)
# (3,)
# 497973
# (1, 10, 3)
# (3,)
# 497974
# (1, 10, 3)
# (3,)
# 497975
# (1, 10, 3)
# (3,)
# 497976
# (1, 10, 3)
# (3,)
# 497977
# (1, 10, 3)
# (3,)
# 497978
# (1, 10, 3)
# (3,)
# 497979
# (1, 10, 3)
# (3,)
# 497980
# (1, 10, 3)
# (3,)
# 497981
# (1, 10, 3)
# (3,)
# 497982
# (1, 10, 3)
# (3,)
# 497983
# ...

# %%
data_df = pd.read_csv('von_karman_data.csv')
experiment_path = vk_rnn
params = pd.read_csv(experiment_path + "/params.csv")
input_length = int(params.iloc[0]['input_length'])
output_length = int(params.iloc[0]['output_length'])
input_width = int(params.iloc[0]['input_width'])
hidden_size = int(params.iloc[0]['hidden_size'])
num_layers = int(params.iloc[0]['num_layers'])
tpm = np.load('tpm.npy')
print(input_length, output_length, input_width, hidden_size, num_layers)
# tpm = np.load('tpm.npy')
model = models.RecurrentModel(input_width=input_width, input_length=input_length, output_length=output_length, hidden_size=hidden_size, num_layers=num_layers)

# Model(input_width=input_width, input_length=input_length, output_length=output_length)
model.load_state_dict(torch.load(experiment_path + '/weights.pt'))
# visualizations.display_preds(model, data_df, input_length, ['u', 'v', 'w'])
vk_rnn_preds, trues = visualizations.get_preds(model, data_df, input_length, ['u', 'v', 'w'])
# Out:
# 50 10 3 50 2
# 500000
# 497950
# (1, 10, 3)
# (3,)
# 497951
# (1, 10, 3)
# (3,)
# 497952
# (1, 10, 3)
# (3,)
# 497953
# (1, 10, 3)
# (3,)
# 497954
# (1, 10, 3)
# (3,)
# 497955
# (1, 10, 3)
# (3,)
# 497956
# (1, 10, 3)
# (3,)
# 497957
# (1, 10, 3)
# (3,)
# 497958
# (1, 10, 3)
# (3,)
# 497959
# (1, 10, 3)
# (3,)
# 497960
# (1, 10, 3)
# (3,)
# 497961
# (1, 10, 3)
# (3,)
# 497962
# (1, 10, 3)
# (3,)
# 497963
# (1, 10, 3)
# (3,)
# 497964
# (1, 10, 3)
# (3,)
# 497965
# (1, 10, 3)
# (3,)
# 497966
# (1, 10, 3)
# (3,)
# 497967
# (1, 10, 3)
# (3,)
# 497968
# (1, 10, 3)
# (3,)
# 497969
# (1, 10, 3)
# (3,)
# 497970
# (1, 10, 3)
# (3,)
# 497971
# (1, 10, 3)
# (3,)
# 497972
# (1, 10, 3)
# (3,)
# 497973
# (1, 10, 3)
# (3,)
# 497974
# (1, 10, 3)
# (3,)
# 497975
# (1, 10, 3)
# (3,)
# 497976
# (1, 10, 3)
# (3,)
# 497977
# (1, 10, 3)
# (3,)
# 497978
# (1, 10, 3)
# (3,)
# 497979
# (1, 10, 3)
# (3,)
# 497980
# (1, 10, 3)
# (3,)
# 497981
# (1, 10, 3)
# (3,)
# 497982
# (1, 10, 3)
# (3,)
# 497983
# ...

# %%
data_df = pd.read_csv('von_karman_data.csv')
experiment_path = vk_lstm
params = pd.read_csv(experiment_path + "/params.csv")
input_length = int(params.iloc[0]['input_length'])
output_length = int(params.iloc[0]['output_length'])
input_width = int(params.iloc[0]['input_width'])
hidden_size = int(params.iloc[0]['hidden_size'])
num_layers = int(params.iloc[0]['num_layers'])
tpm = np.load('tpm.npy')
print(input_length, output_length, input_width, hidden_size, num_layers)
# tpm = np.load('tpm.npy')
model = models.LSTMModel(input_width=input_width,
                         input_length=input_length,
                         output_length=output_length,
                         hidden_size=hidden_size,
                         num_layers=num_layers)

# Model(input_width=input_width, input_length=input_length, output_length=output_length)
model.load_state_dict(torch.load(experiment_path + '/weights.pt'))
# visualizations.display_preds(model, data_df, input_length, ['u', 'v', 'w'])
vk_lstm_preds, trues = visualizations.get_preds(model, data_df, input_length, ['u', 'v', 'w'])
# Out:
# 50 10 3 50 2
# 500000
# 497950
# (1, 10, 3)
# (3,)
# 497951
# (1, 10, 3)
# (3,)
# 497952
# (1, 10, 3)
# (3,)
# 497953
# (1, 10, 3)
# (3,)
# 497954
# (1, 10, 3)
# (3,)
# 497955
# (1, 10, 3)
# (3,)
# 497956
# (1, 10, 3)
# (3,)
# 497957
# (1, 10, 3)
# (3,)
# 497958
# (1, 10, 3)
# (3,)
# 497959
# (1, 10, 3)
# (3,)
# 497960
# (1, 10, 3)
# (3,)
# 497961
# (1, 10, 3)
# (3,)
# 497962
# (1, 10, 3)
# (3,)
# 497963
# (1, 10, 3)
# (3,)
# 497964
# (1, 10, 3)
# (3,)
# 497965
# (1, 10, 3)
# (3,)
# 497966
# (1, 10, 3)
# (3,)
# 497967
# (1, 10, 3)
# (3,)
# 497968
# (1, 10, 3)
# (3,)
# 497969
# (1, 10, 3)
# (3,)
# 497970
# (1, 10, 3)
# (3,)
# 497971
# (1, 10, 3)
# (3,)
# 497972
# (1, 10, 3)
# (3,)
# 497973
# (1, 10, 3)
# (3,)
# 497974
# (1, 10, 3)
# (3,)
# 497975
# (1, 10, 3)
# (3,)
# 497976
# (1, 10, 3)
# (3,)
# 497977
# (1, 10, 3)
# (3,)
# 497978
# (1, 10, 3)
# (3,)
# 497979
# (1, 10, 3)
# (3,)
# 497980
# (1, 10, 3)
# (3,)
# 497981
# (1, 10, 3)
# (3,)
# 497982
# (1, 10, 3)
# (3,)
# 497983
# ...

# %%
data_df = pd.read_csv('von_karman_data.csv')
experiment_path = vk_transformer
params = pd.read_csv(experiment_path + "/params.csv")
input_length = int(params.iloc[0]['input_length'])
output_length = int(params.iloc[0]['output_length'])
input_width = int(params.iloc[0]['input_width'])
hidden_size = int(params.iloc[0]['hidden_size'])
num_layers = int(params.iloc[0]['num_layers'])
tpm = np.load('tpm.npy')
print(input_length, output_length, input_width, hidden_size, num_layers)
# tpm = np.load('tpm.npy')
model = models.TransformerModel(input_width=input_width,
                         input_length=input_length,
                         output_length=output_length,
                         hidden_size=hidden_size,
                         num_layers=num_layers,
                         lags=True)

# Model(input_width=input_width, input_length=input_length, output_length=output_length)
model.load_state_dict(torch.load(experiment_path + '/weights.pt'))
# visualizations.display_preds(model, data_df, input_length, ['u', 'v', 'w'])
vk_transformer_preds, trues = visualizations.get_preds(model, data_df, input_length, ['u', 'v', 'w'])
# Out:
# 50 10 3 50 2
# 500000
# 497950
# (1, 10, 3)
# (3,)
# 497951
# (1, 10, 3)
# (3,)
# 497952
# (1, 10, 3)
# (3,)
# 497953
# (1, 10, 3)
# (3,)
# 497954
# (1, 10, 3)
# (3,)
# 497955
# (1, 10, 3)
# (3,)
# 497956
# (1, 10, 3)
# (3,)
# 497957
# (1, 10, 3)
# (3,)
# 497958
# (1, 10, 3)
# (3,)
# 497959
# (1, 10, 3)
# (3,)
# 497960
# (1, 10, 3)
# (3,)
# 497961
# (1, 10, 3)
# (3,)
# 497962
# (1, 10, 3)
# (3,)
# 497963
# (1, 10, 3)
# (3,)
# 497964
# (1, 10, 3)
# (3,)
# 497965
# (1, 10, 3)
# (3,)
# 497966
# (1, 10, 3)
# (3,)
# 497967
# (1, 10, 3)
# (3,)
# 497968
# (1, 10, 3)
# (3,)
# 497969
# (1, 10, 3)
# (3,)
# 497970
# (1, 10, 3)
# (3,)
# 497971
# (1, 10, 3)
# (3,)
# 497972
# (1, 10, 3)
# (3,)
# 497973
# (1, 10, 3)
# (3,)
# 497974
# (1, 10, 3)
# (3,)
# 497975
# (1, 10, 3)
# (3,)
# 497976
# (1, 10, 3)
# (3,)
# 497977
# (1, 10, 3)
# (3,)
# 497978
# (1, 10, 3)
# (3,)
# 497979
# (1, 10, 3)
# (3,)
# 497980
# (1, 10, 3)
# (3,)
# 497981
# (1, 10, 3)
# (3,)
# 497982
# (1, 10, 3)
# (3,)
# 497983
# ...

# %%
data_df = pd.read_csv('von_karman_data.csv')
experiment_path = vk_annmc
params = pd.read_csv(experiment_path + "/params.csv")
input_length = int(params.iloc[0]['input_length'])
output_length = int(params.iloc[0]['output_length'])
input_width = int(params.iloc[0]['input_width'])
hidden_size = int(params.iloc[0]['hidden_size'])
num_layers = int(params.iloc[0]['num_layers'])
tpm = np.load('tpm.npy')
print(input_length, output_length, input_width, hidden_size, num_layers)
# tpm = np.load('tpm.npy')
model = models.ANNMCModel(input_width=input_width,
                         input_length=input_length,
                         output_length=output_length,
                         tpm=tpm)

# Model(input_width=input_width, input_length=input_length, output_length=output_length)
model.load_state_dict(torch.load(experiment_path + '/weights.pt'))
# visualizations.display_preds(model, data_df, input_length, ['u', 'v', 'w'])
vk_annmc_preds, trues = visualizations.get_preds(model, data_df, input_length, ['u', 'v', 'w'])
# Out:
# 50 10 3 50 2
# 500000
# 497950
# (1, 10, 3)
# (3,)
# 497951
# (1, 10, 3)
# (3,)
# 497952
# (1, 10, 3)
# (3,)
# 497953
# (1, 10, 3)
# (3,)
# 497954
# (1, 10, 3)
# (3,)
# 497955
# (1, 10, 3)
# (3,)
# 497956
# (1, 10, 3)
# (3,)
# 497957
# (1, 10, 3)
# (3,)
# 497958
# (1, 10, 3)
# (3,)
# 497959
# (1, 10, 3)
# (3,)
# 497960
# (1, 10, 3)
# (3,)
# 497961
# (1, 10, 3)
# (3,)
# 497962
# (1, 10, 3)
# (3,)
# 497963
# (1, 10, 3)
# (3,)
# 497964
# (1, 10, 3)
# (3,)
# 497965
# (1, 10, 3)
# (3,)
# 497966
# (1, 10, 3)
# (3,)
# 497967
# (1, 10, 3)
# (3,)
# 497968
# (1, 10, 3)
# (3,)
# 497969
# (1, 10, 3)
# (3,)
# 497970
# (1, 10, 3)
# (3,)
# 497971
# (1, 10, 3)
# (3,)
# 497972
# (1, 10, 3)
# (3,)
# 497973
# (1, 10, 3)
# (3,)
# 497974
# (1, 10, 3)
# (3,)
# 497975
# (1, 10, 3)
# (3,)
# 497976
# (1, 10, 3)
# (3,)
# 497977
# (1, 10, 3)
# (3,)
# 497978
# (1, 10, 3)
# (3,)
# 497979
# (1, 10, 3)
# (3,)
# 497980
# (1, 10, 3)
# (3,)
# 497981
# (1, 10, 3)
# (3,)
# 497982
# (1, 10, 3)
# (3,)
# 497983
# ...

# %%
print(np.array(vk_persistent_preds).shape)
# Out:
# (2000, 3)

# %%
trues = np.array(trues)
vk_persistent_preds = np.array(vk_persistent_preds)
vk_lin_reg_preds = np.array(vk_lin_reg_preds)
vk_lin_reg_flat_preds = np.array(vk_lin_reg_flat_preds)
# vk_deep_1_preds = np.array(vk_deep_1_preds)
vk_deep_2_preds = np.array(vk_deep_2_preds)
# vk_deep_3_preds = np.array(vk_deep_3_preds)
vk_rnn_preds = np.array(vk_rnn_preds)
vk_lstm_preds = np.array(vk_lstm_preds)
vk_transformer_preds = np.array(vk_transformer_preds)
vk_annmc_preds = np.array(vk_annmc_preds)

# %%
print(vk_persistent_preds.shape)
# Out:
# (1999, 3)

# %%
size = 50
t = np.arange(0, 0.1 * size, 0.1)

# %%
plt.plot(t, trues[:size, 0], label="True")
plt.plot(t, vk_persistent_preds[:size, 0], '--', label="Persistent")
plt.plot(t, vk_lin_reg_preds[:size, 0], '--', label="Lin_reg")
plt.plot(t, vk_lin_reg_flat_preds[:size, 0], '--', label="Lin_reg_flat")
# plt.plot(t, vk_deep_1_preds[:size, 0], '--', label="Deep_1")
plt.plot(t, vk_deep_2_preds[:size, 0], '--', label="Deep")
# plt.plot(t, vk_deep_3_preds[:size, 0], '--', label="Deep_3")
plt.plot(t, vk_rnn_preds[:size, 0], '--', label="RNN")
plt.plot(t, vk_lstm_preds[:size, 0], '--', label="LSTM")
plt.plot(t, vk_transformer_preds[:size, 0], '--', label="Transformer")
plt.plot(t, vk_annmc_preds[:size, 0], '--', label="ANN-MC")
plt.title("")
plt.legend()

# %%
plt.plot(t, trues[:size, 0], label="True")
plt.plot(t, vk_persistent_preds[:size, 0], '--', label="Persistent")
plt.plot(t, vk_lin_reg_preds[:size, 0], '--', label="Lin_reg")
plt.plot(t, vk_lin_reg_flat_preds[:size, 0], '--', label="Lin_reg_flat")
# plt.plot(t, vk_deep_1_preds[:size, 0], '--', label="Deep_1")
plt.plot(t, vk_deep_2_preds[:size, 0], '--', label="Deep")
# plt.plot(t, vk_deep_3_preds[:size, 0], '--', label="Deep_3")
plt.plot(t, vk_rnn_preds[:size, 0], '--', label="RNN")
plt.plot(t, vk_lstm_preds[:size, 0], '--', label="LSTM")
plt.plot(t, vk_transformer_preds[:size, 0], '--', label="Transformer")
plt.plot(t, vk_annmc_preds[:size, 0], '--', label="ANN-MC")
plt.title("Sample Predictions of von Karman Models on Test Set")
plt.xlabel("Time (s)")
plt.ylabel("u component of wind (m/s)")
plt.legend()
