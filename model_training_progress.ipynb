# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
best_losses = {}

# %%
df = pd.read_csv('/home/dylaneg/Documents/Programming/IROM/FutureFlow/FutureFlow/experiments/Naive_2023-12-10_18:04:39/log.csv')
plt.plot(df['train_losses'], label='train')
plt.plot(df['test_losses'], label='val')
plt.legend()
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Loss Curve of Naive')
plt.show()

best_losses['Naive'] = df['test_losses'].iloc[-1]

# %%
df = pd.read_csv('/home/dylaneg/Documents/Programming/IROM/FutureFlow/FutureFlow/experiments/Lin_Reg_2023-11-15_00:26:31/log.csv')
plt.plot(df['train_losses'], label='train')
plt.plot(df['test_losses'], label='val')
plt.legend()
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Loss Curve of Lin Reg')
plt.show()

best_losses['Lin_Reg'] = df['test_losses'].iloc[-1]

# %%
df = pd.read_csv('/home/dylaneg/Documents/Programming/IROM/FutureFlow/FutureFlow/experiments/Lin_Reg_Flat_2023-11-14_23:40:29/log.csv')
plt.plot(df['train_losses'], label='train')
plt.plot(df['test_losses'], label='val')
plt.legend()
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Loss Curve of Lin Reg Flat')
plt.show()

best_losses['Lin_Reg_Flat'] = df['test_losses'].iloc[-1]

# %%
df = pd.read_csv('/home/dylaneg/Documents/Programming/IROM/FutureFlow/FutureFlow/experiments/Deep_Reg_2023-12-10_18:30:43/log.csv')
plt.plot(df['train_losses'], label='train')
plt.plot(df['test_losses'], label='val')
plt.legend()
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Loss Curve of Deep Reg')
plt.show()

best_losses['Deep_Reg'] = df['test_losses'].iloc[-1]

# %%
df = pd.read_csv('/home/dylaneg/Documents/Programming/IROM/FutureFlow/FutureFlow/experiments/RNN_2023-12-10_21:22:35/log.csv')
plt.plot(df['train_losses'], label='train')
plt.plot(df['test_losses'], label='val')
plt.legend()
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Loss Curve of RNN')
plt.show()

best_losses['RNN'] = df['test_losses'].iloc[-1]

# %%
df = pd.read_csv('/home/dylaneg/Documents/Programming/IROM/FutureFlow/FutureFlow/experiments/LSTM_2023-11-15_00:35:21/log.csv')
plt.plot(df['train_losses'], label='train')
plt.plot(df['test_losses'], label='val')
plt.legend()
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Loss Curve of LSTM')
plt.show()

best_losses['LSTM'] = df['test_losses'].iloc[-1]

# %%
df = pd.read_csv('/home/dylaneg/Documents/Programming/IROM/FutureFlow/FutureFlow/experiments/Transformer_2023-12-04_16:00:21/log.csv')
plt.plot(df['train_losses'], label='train')
plt.plot(df['test_losses'], label='val')
plt.legend()
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Loss Curve of Transformer 1')
plt.show()

best_losses['Transformer_1'] = df['test_losses'].iloc[-1]

# %%
df = pd.read_csv('/home/dylaneg/Documents/Programming/IROM/FutureFlow/FutureFlow/experiments/Transformer2_2023-12-06_17:02:47/log.csv')
plt.plot(df['train_losses'], label='train')
plt.plot(df['test_losses'], label='val')
plt.legend()
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Loss Curve of Transformer 2')
plt.show()

best_losses['Transformer_2'] = df['test_losses'].iloc[-1]

# %%
print(best_losses)
# Out:
# {'Lin_Reg_Flat': 0.3043378801142619, 'Deep_Reg': 0.3035048828469365, 'LSTM': 0.305413901418079, 'Lin_Reg': 0.3207361393631784, 'Naive': 0.3810859765220014, 'Transformer_1': 0.3155268646338406, 'Transformer_2': 0.3100105072557926}

# %%
D = best_losses

# %%
del D['Naive']

# %%
fig, ax = plt.subplots()
plt.bar(range(len(D)), list(D.values()), align='center')
plt.xticks(range(len(D)), list(D.keys()))
plt.ylim([0.3, 0.4])
plt.ylabel('Final Test Loss')
plt.title('Model Comparison')
plt.setp(ax.get_xticklabels(), rotation=30, horizontalalignment='right')
plt.tight_layout()
