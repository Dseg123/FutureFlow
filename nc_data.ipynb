# %%
# !pip install netCDF4
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━━━━━━━━━ 3.7/5.5 MB 15.0 MB/s eta 0:00:01

# %%
from matplotlib import pyplot as plt
import pandas as pd
import netCDF4
fp='/home/dylaneg/Documents/Programming/IROM/FutureFlow/FutureFlow/hr_qc_geo_tiltcor_20161201.nc/isfs_qc_tiltcor_hr_20161201_12.nc'
nc = netCDF4.Dataset(fp)
print(nc)
# Out:
# <class 'netCDF4._netCDF4.Dataset'>
# root group (NETCDF3_CLASSIC data model, file format NETCDF3):
#     history: Created: 2019-02-13 00:07:00 +0000
#
#     NIDAS_version: v1.2-929
#     calibration_file_path: /h/eol/isfs/isfs/projects/Perdigao/ISFS/cal_files/QC/v07:/h/eol/isfs/isfs/projects/Perdigao/ISFS/cal_files/QC:/h/eol/isfs/isfs/cal_files
#     dataset: hr_qc_geo_tiltcor
#     dataset_description: High rate winds in geographic coordinates
#     project_config: /h/eol/isfs/isfs/projects/Perdigao/ISFS/config/perdigao.xml;
#     wind3d_horiz_coordinates: geographic
#     file_length_seconds: 3600
#     wind3d_horiz_rotation: 1
#     wind3d_tilt_correction: 1
#     dimensions(sizes): time(3600), sample(20)
# ...

# %%
print(nc.variables)
# Out:
# {'base_time': <class 'netCDF4._netCDF4.Variable'>
# int32 base_time()
#     units: seconds since 1970-01-01 00:00:00 00:00
# unlimited dimensions:
# current shape = ()
# filling on, default _FillValue of -2147483647 used, 'time': <class 'netCDF4._netCDF4.Variable'>
# float64 time(time)
#     units: seconds since 2016-12-01 12:00:00 00:00
#     interval(sec): 1.0
# unlimited dimensions: time
# current shape = (3600,)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'Ifan_100m_tse04': <class 'netCDF4._netCDF4.Variable'>
# float32 Ifan_100m_tse04(time)
#     _FillValue: 1e+37
#     long_name: Aspiration fan current, NCAR hygrothermometer
#     short_name: Ifan.100m.tse04
#     units: mA
# unlimited dimensions: time
# current shape = (3600,)
# filling on, 'Ifan_100m_tse09': <class 'netCDF4._netCDF4.Variable'>
# float32 Ifan_100m_tse09(time)
#     _FillValue: 1e+37
#     long_name: Aspiration fan current, NCAR hygrothermometer
#     short_name: Ifan.100m.tse09
# ...

# %%
print(list(nc.variables))
# Out:
# ['base_time', 'time', 'Ifan_100m_tse04', 'Ifan_100m_tse09', 'Ifan_100m_tse13', 'Ifan_10m_rsw03', 'Ifan_10m_rsw06', 'Ifan_10m_tnw02', 'Ifan_10m_tnw03', 'Ifan_10m_tnw05', 'Ifan_10m_tnw07', 'Ifan_10m_tnw10', 'Ifan_10m_tnw11', 'Ifan_10m_tse04', 'Ifan_10m_tse06', 'Ifan_10m_tse09', 'Ifan_10m_tse11', 'Ifan_10m_tse13', 'Ifan_20m_rsw03', 'Ifan_20m_rsw06', 'Ifan_20m_tnw07', 'Ifan_20m_tnw10', 'Ifan_20m_tnw11', 'Ifan_20m_tse04', 'Ifan_20m_tse06', 'Ifan_20m_tse09', 'Ifan_20m_tse11', 'Ifan_20m_tse13', 'Ifan_2m_rsw03', 'Ifan_2m_rsw06', 'Ifan_2m_tnw02', 'Ifan_2m_tnw03', 'Ifan_2m_tnw05', 'Ifan_2m_tnw07', 'Ifan_2m_tnw10', 'Ifan_2m_tnw11', 'Ifan_2m_tse04', 'Ifan_2m_tse06', 'Ifan_2m_tse09', 'Ifan_2m_tse11', 'Ifan_2m_tse13', 'Ifan_40m_rsw03', 'Ifan_40m_rsw06', 'Ifan_40m_tnw07', 'Ifan_40m_tnw10', 'Ifan_40m_tse04', 'Ifan_40m_tse06', 'Ifan_40m_tse09', 'Ifan_40m_tse11', 'Ifan_40m_tse13', 'Ifan_60m_rsw03', 'Ifan_60m_rsw06', 'Ifan_60m_tnw07', 'Ifan_60m_tnw10', 'Ifan_60m_tse04', 'Ifan_60m_tse06', 'Ifan_60m_tse0
# ...

# %%
print(nc['time'][:])
# Out:
# [5.0000e-01 1.5000e+00 2.5000e+00 ... 3.5975e+03 3.5985e+03 3.5995e+03]

# %%
print(nc['v_8m_tnw04'][:])
# Out:
# [[-- -- -- ... -- -- --]
#  [-- -- -- ... -- -- --]
#  [-- -- -- ... -- -- --]
#  ...
#  [-- -- -- ... -- -- --]
#  [-- -- -- ... -- -- --]
#  [-- -- -- ... -- -- --]]

# %%
print(list(nc['u_8m_tnw04']))
# Out:
# [masked_array(data=[--, --, --, --, --, --, --, --, --, --, --, --, --, --,
#                    --, --, --, --, --, --],
#              mask=[ True,  True,  True,  True,  True,  True,  True,  True,
#                     True,  True,  True,  True,  True,  True,  True,  True,
#                     True,  True,  True,  True],
#        fill_value=1e+37,
#             dtype=float32), masked_array(data=[--, --, --, --, --, --, --, --, --, --, --, --, --, --,
#                    --, --, --, --, --, --],
#              mask=[ True,  True,  True,  True,  True,  True,  True,  True,
#                     True,  True,  True,  True,  True,  True,  True,  True,
#                     True,  True,  True,  True],
#        fill_value=1e+37,
#             dtype=float32), masked_array(data=[--, --, --, --, --, --, --, --, --, --, --, --, --, --,
#                    --, --, --, --, --, --],
#              mask=[ True,  True,  True,  True,  True,  True,  True,  True,
# ...

# %%
print(list(nc['time']))
# Out:
# [masked_array(data=0.5,
#              mask=False,
#        fill_value=1e+20), masked_array(data=1.5,
#              mask=False,
#        fill_value=1e+20), masked_array(data=2.5,
#              mask=False,
#        fill_value=1e+20), masked_array(data=3.5,
#              mask=False,
#        fill_value=1e+20), masked_array(data=4.5,
#              mask=False,
#        fill_value=1e+20), masked_array(data=5.5,
#              mask=False,
#        fill_value=1e+20), masked_array(data=6.5,
#              mask=False,
#        fill_value=1e+20), masked_array(data=7.5,
#              mask=False,
#        fill_value=1e+20), masked_array(data=8.5,
#              mask=False,
#        fill_value=1e+20), masked_array(data=9.5,
#              mask=False,
#        fill_value=1e+20), masked_array(data=10.5,
#              mask=False,
#        fill_value=1e+20), masked_array(data=11.5,
#              mask=False,
#        fill_value=1e+20), masked_array(data=12.5,
#              mask=False,
# ...

# %%
df = pd.read_csv('sample_data.csv')

# %%
diff = (df - df.shift(1)).iloc[1:]

# %%
print(diff.reset_index().drop(columns=['index']))
# Out:
#                u         v        w
# 0      -0.228463  0.372565 -0.21000
# 1      -0.343872 -0.051962  0.76275
# 2       0.294100 -0.208875 -0.01400
# 3      -0.011176 -0.239004 -0.62475
# 4      -0.116962 -0.229192  0.11375
# ...          ...       ...      ...
# 491884  1.057192 -0.321244 -0.02125
# 491885 -1.422854 -0.524738  0.58850
# 491886  0.762879 -0.351860 -0.56850
# 491887  0.685669  0.303259  0.22200
# 491888 -1.444918  0.047671  0.25125
#
# [491889 rows x 3 columns]

# %%
df['u'].plot()
# Out:
# <Axes: >

# %%
diff['u'].plot()
# Out:
# <Axes: >

# %%
for i in range(10):
    df = df - df.shift(1)
    df = df.iloc[1:]

# %%
print(df.reset_index())
# Out:
#          index         u         v        w
# 0            0  0.379934 -0.977337 -0.30325
# 1            1  0.151470 -0.604772 -0.51325
# 2            2 -0.192402 -0.656734  0.24950
# 3            3  0.101699 -0.865609  0.23550
# 4            4  0.090522 -1.104613 -0.38925
# ...        ...       ...       ...      ...
# 491885  491885  3.547087  0.005302 -0.23800
# 491886  491886  2.124233 -0.519437  0.35050
# 491887  491887  2.887112 -0.871297 -0.21800
# 491888  491888  3.572781 -0.568037  0.00400
# 491889  491889  2.127863 -0.520366  0.25525
#
# [491890 rows x 4 columns]

# %%
params = {'a': [1], 'b': [2], 'c': [3]}
df = pd.DataFrame(params)

# %%
print(df)
# Out:
#    a  b  c
# 0  1  2  3
